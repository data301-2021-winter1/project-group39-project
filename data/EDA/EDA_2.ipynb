# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt

# %%
EDA_df=pd.read_csv("../raw/raw_data.csv")
EDA_df
# Out:
#     Filter              ReportDate  TotalCases  CaseDelta  TotalTests  \
# 0      NaN  03/04/2020 03:00:00 PM           0          0         NaN
# 1      NaN  03/05/2020 03:00:00 PM           3          3         NaN
# 2      NaN  03/06/2020 03:00:00 PM           3          0         NaN
# 3      NaN  03/07/2020 03:00:00 PM           3          0         NaN
# 4      NaN  03/08/2020 02:00:00 PM           5          2         NaN
# ..     ...                     ...         ...        ...         ...
# 578    NaN  10/03/2021 02:00:00 PM      536249       1092  13124215.0
# 579    NaN  10/04/2021 02:00:00 PM      537327       1078  13157036.0
# 580    NaN  10/05/2021 02:00:00 PM      537976        649  13181280.0
# 581    NaN  10/06/2021 02:00:00 PM      539053       1077  13217318.0
# 582      d  10/07/2021 02:00:00 PM      540451       1398  13264030.0
#
#      TestsDelta  PosTestPercent  PosPercentDiff  NegativeTests  NegDelta  ...  \
# ...

# %%
EDA_df.shape
# Out:
# (583, 159)

# %%
EDA_df.head()
# Out:
#   Filter              ReportDate  TotalCases  CaseDelta  TotalTests  \
# 0    NaN  03/04/2020 03:00:00 PM           0          0         NaN
# 1    NaN  03/05/2020 03:00:00 PM           3          3         NaN
# 2    NaN  03/06/2020 03:00:00 PM           3          0         NaN
# 3    NaN  03/07/2020 03:00:00 PM           3          0         NaN
# 4    NaN  03/08/2020 02:00:00 PM           5          2         NaN
#
#    TestsDelta  PosTestPercent  PosPercentDiff  NegativeTests  NegDelta  ...  \
# 0         NaN             NaN             NaN            NaN       NaN  ...
# 1         NaN             NaN             NaN            NaN       NaN  ...
# 2         NaN             NaN             NaN            NaN       NaN  ...
# 3         NaN             NaN             NaN            NaN       NaN  ...
# 4         NaN             NaN             NaN            NaN       NaN  ...
#
#    pDeathAgeUnknown  pDeathGenMale  pDeathGenFemale  pDeathGenUnkn  \
# ...

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
EDA_df.nunique(axis=0)
EDA_df.describe().apply(lambda s: s.apply(lambda x: format(x, 'f')))
# Out:
#           TotalCases    CaseDelta       TotalTests    TestsDelta  \
# count     583.000000   583.000000       577.000000    576.000000
# mean   259070.728988   927.017153   5691716.788562  23037.970486
# std    182219.039712   740.585593   4395496.016899  13552.825088
# min         0.000000     0.000000         1.000000      7.000000
# 25%     85200.000000   441.500000   1245767.000000  12086.000000
# 50%    250808.000000   763.000000   5419999.000000  22317.500000
# 75%    455446.000000  1163.000000  10107961.000000  32481.500000
# max    540451.000000  3792.000000  13264030.000000  66618.000000
#
#       PosTestPercent PosPercentDiff   NegativeTests      NegDelta  \
# count     577.000000     556.000000      560.000000    559.000000
# mean        6.058769      -0.041709  2229643.278571   7591.515206
# std         5.476473       0.228488  1344714.231631   3744.256174
# min         0.540000      -1.840000     9988.000000    838.000000
# ...

# %%
df_cleaned = EDA_df.dropna(axis=0)

# %%
sns.pairplot(EDA_df)
